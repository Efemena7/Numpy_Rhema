# %% [markdown]
# # Histogram and examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.histogram([1,2,1],bins=[0,1,2,3])
# Out:
# (array([0, 2, 1], dtype=int64), array([0, 1, 2, 3]))

# %%
data=np.array([5,10,15,18,20])
bins=7
graph=np.histogram(data,bins)
plt.hist(data,bins);

# %%
data=np.array([6,18,36,40])
bins=5
graph=np.histogram(data,bins)
plt.hist(data,bins)
# Out:
# (array([1., 1., 0., 0., 2.]),
#  array([ 6. , 12.8, 19.6, 26.4, 33.2, 40. ]),
#  <BarContainer object of 5 artists>)

# %%
scores=np.random.randint(0,100,10)

# %%
scores
# Out:
# array([86, 54, 95, 58, 33, 52, 28,  8, 16, 42])

# %%
plt.hist(scores,bins=7,edgecolor="red");

# %%
plt.hist(scores,bins=9,edgecolor="red");

# %% [markdown]
# # Scatter plot

# %%
men=np.random.randint(20,59,10)
women=np.random.randint(18,39,10)

# %%
plt.scatter(men,women,c="red");

# %%
plt.scatter(men,women,c="green",linewidths=4,s=100);
plt.xlabel("MEN");
plt.ylabel("WOMEN");

# %% [markdown]
# #  $Box plot$

# %%
age=np.random.randint(10, 50,20)

# %%
age
# Out:
# array([36, 43, 19, 17, 40, 29, 28, 47, 37, 12, 44, 42, 33, 46, 41, 35, 38,
#        22, 24, 27])

# %%
plt.boxplot(age);

# %% [markdown]
# # Universal Functions
# Universal functions in numpy are simple mathematical functins. it is just a term that we gave to mathematical functions

# %% [markdown]
# # Trigonometric function
# These functions work on radians, so angles need to be converted to radians by multiplying by pi/180. Only then we can call trigonometric functions. They take an array as input arguments.

# %%
# Python code to demonstrate trigonometric function  

# create an array of angles 
angles = np.array([0, 30, 45, 60, 90, 75, 105, 180]) 

# conversion of degree into radians 
# using deg2rad function 
radians = np.deg2rad(angles) 

# cosine of angles 
print('Sine of angles in the array:') 
cosine_value = np.cos(radians) 
print(np.cos(radians)) 
print()

# inverse cosine of sine values 
print('Inverse cosine of sine values:') 
print(np.rad2deg(np.arccos(cosine_value))) 
print()

# hyperbolic cosine of angles 
print('cosine hyperbolic of angles in the array:') 
cosineh_value = np.cosh(radians) 
print(np.cosh(radians)) 
print()

# inverse cosine hyperbolic 
print('Inverse cosine hyperbolic:') 
print(np.cos(cosineh_value)) 
print()

# hypot function demonstration 
base = 8
height = 12
print('hypotenuse of right triangle is:') 
print(np.hypot(base, height))
# Out:
# Sine of angles in the array:
# [ 1.00000000e+00  8.66025404e-01  7.07106781e-01  5.00000000e-01
#   6.12323400e-17  2.58819045e-01 -2.58819045e-01 -1.00000000e+00]
#
# Inverse cosine of sine values:
# [  0.  30.  45.  60.  90.  75. 105. 180.]
#
# cosine hyperbolic of angles in the array:
# [ 1.          1.14023832  1.32460909  1.60028686  2.50917848  1.98627445
#   3.20504339 11.59195328]
#
# Inverse cosine hyperbolic:
# [ 0.54030231  0.41737795  0.24370794 -0.02948626 -0.80660286 -0.40362742
#  -0.99798768  0.56165023]
#
# hypotenuse of right triangle is:
# 14.422205101855956

# %% [markdown]
# # statistical function
# These functions are used to calculate mean, median, variance, minimum of array elements.

# %%
# Python code demonstrate statistical function  

# construct a weight array 
weight = np.array([50.7, 52.5, 50, 58, 55.63, 73.25, 49.5, 45]) 

# minimum and maximum 
print('Minimum and maximum weight of the students: ') 
print(np.amin(weight), np.amax(weight)) 
print()

# range of weight i.e. max weight-min weight 
print('Range of the weight of the students: ') 
print(np.ptp(weight)) 
print()

# percentile 
print('Weight below which 70 % student fall: ') 
print(np.percentile(weight, 70)) 
print()

# mean 
print('Mean weight of the students: ') 
print(np.mean(weight)) 
print()

# median 
print('Median weight of the students: ') 
print(np.median(weight)) 
print()

# standard deviation 
print('Standard deviation of weight of the students: ') 
print(np.std(weight)) 
print()
print()

# variance 
print('Variance of weight of the students: ') 
print(np.var(weight)) 
print()

# average 
print('Average weight of the students: ') 
print(np.average(weight))

# %% [markdown]
# # Bit-twiddling functions
# These functions accept integer values as input arguments and perform bitwise operations on binary representations of those integers.

# %%
# Python code to demonstrate bitwise-function 

# construct an array of even and odd numbers 
even = np.array([0, 2, 4, 6, 8, 16, 32]) 
odd = np.array([1, 3, 5, 7, 9, 17, 33]) 

# bitwise_and 
print('bitwise_and of two arrays: ') 
print(np.bitwise_and(even, odd)) 
print()

# bitwise_or 
print('bitwise_or of two arrays: ') 
print(np.bitwise_or(even, odd)) 
print()

# bitwise_xor 
print('bitwise_xor of two arrays: ') 
print(np.bitwise_xor(even, odd)) 
print()

# invert or not 
print('inversion of even no. array: ') 
print(np.invert(even)) 
print()

# left_shift 
print('left_shift of even no. array: ') 
print(np.left_shift(even, 1)) 
print()

# right_shift 
print('right_shift of even no. array: ') 
print(np.right_shift(even, 1))
# Out:
# bitwise_and of two arrays:
# [ 0  2  4  6  8 16 32]
#
# bitwise_or of two arrays:
# [ 1  3  5  7  9 17 33]
#
# bitwise_xor of two arrays:
# [1 1 1 1 1 1 1]
#
# inversion of even no. array:
# [ -1  -3  -5  -7  -9 -17 -33]
#
# left_shift of even no. array:
# [ 0  4  8 12 16 32 64]
#
# right_shift of even no. array:
# [ 0  1  2  3  4  8 16]
